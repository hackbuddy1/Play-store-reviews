# %% [markdown]
# # Google Play Store Sentiment Analysis

# %%
import pandas as pd


file_path = "reviews.csv" 


df = pd.read_csv(file_path)


print(df.head())
# Out:
#                                             reviewId  \
# 0  gp:AOqpTOEhZuqSqqWnaKRgv-9ABYdajFUB0WugPGh-SG-...
# 1  gp:AOqpTOH0WP4IQKBZ2LrdNmFy_YmpPCVrV3diEU9KGm3...
# 2  gp:AOqpTOEMCkJB8Iq1p-r9dPwnSYadA5BkPWTf32Z1azu...
# 3  gp:AOqpTOGFrUWuKGycpje8kszj3uwHN6tU_fd4gLVFy9z...
# 4  gp:AOqpTOHls7DW8wmDFzTkHwxuqFkdNQtKHmO6Pt9jhZE...
#
#                            userName  \
# 0                          Eric Tie
# 1                        john alpha
# 2                       Sudhakar .S
# 3  SKGflorida@bellsouth.net DAVID S
# 4                     Louann Stoker
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a-/AOh14...
# 3  https://play-lh.googleusercontent.com/-75aK0WF...
# 4  https://play-lh.googleusercontent.com/-pBcY_Z-...
#
#                                              content  score  thumbsUpCount  \
# 0                      I cannot open the app anymore      1              0
# 1  I have been begging for a refund from this app...      1              0
# 2  Very costly for the premium version (approx In...      1              0
# 3  Used to keep me organized, but all the 2020 UP...      1              0
# 4                                Dan Birthday Oct 28      1              0
#
#   reviewCreatedVersion                   at  \
# 0              5.4.0.6  2020-10-27 21:24:41
# 1                  NaN  2020-10-27 14:03:28
# 2                  NaN  2020-10-27 08:18:40
# 3                  NaN  2020-10-26 13:28:07
# 4              5.6.0.7  2020-10-26 06:10:50
#
#                                         replyContent            repliedAt  \
# 0                                                NaN                  NaN
# 1  Please note that from checking our records, yo...  2020-10-27 15:05:52
# 2                                                NaN                  NaN
# 3  What do you find troublesome about the update?...  2020-10-26 14:58:29
# 4                                                NaN                  NaN
#
#   sortOrder      appId
# 0    newest  com.anydo
# 1    newest  com.anydo
# 2    newest  com.anydo
# 3    newest  com.anydo
# 4    newest  com.anydo

# %% [markdown]
# # 1. How big is the data?

# %%
df.shape
# Out:
# (12495, 12)

# %% [markdown]
# # 2. How does the data look like?

# %%
df.head()
# Out:
#                                             reviewId  \
# 0  gp:AOqpTOEhZuqSqqWnaKRgv-9ABYdajFUB0WugPGh-SG-...
# 1  gp:AOqpTOH0WP4IQKBZ2LrdNmFy_YmpPCVrV3diEU9KGm3...
# 2  gp:AOqpTOEMCkJB8Iq1p-r9dPwnSYadA5BkPWTf32Z1azu...
# 3  gp:AOqpTOGFrUWuKGycpje8kszj3uwHN6tU_fd4gLVFy9z...
# 4  gp:AOqpTOHls7DW8wmDFzTkHwxuqFkdNQtKHmO6Pt9jhZE...
#
#                            userName  \
# 0                          Eric Tie
# 1                        john alpha
# 2                       Sudhakar .S
# 3  SKGflorida@bellsouth.net DAVID S
# 4                     Louann Stoker
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a-/AOh14...
# 3  https://play-lh.googleusercontent.com/-75aK0WF...
# 4  https://play-lh.googleusercontent.com/-pBcY_Z-...
#
#                                              content  score  thumbsUpCount  \
# 0                      I cannot open the app anymore      1              0
# 1  I have been begging for a refund from this app...      1              0
# 2  Very costly for the premium version (approx In...      1              0
# 3  Used to keep me organized, but all the 2020 UP...      1              0
# 4                                Dan Birthday Oct 28      1              0
#
#   reviewCreatedVersion                   at  \
# 0              5.4.0.6  2020-10-27 21:24:41
# 1                  NaN  2020-10-27 14:03:28
# 2                  NaN  2020-10-27 08:18:40
# 3                  NaN  2020-10-26 13:28:07
# 4              5.6.0.7  2020-10-26 06:10:50
#
#                                         replyContent            repliedAt  \
# 0                                                NaN                  NaN
# 1  Please note that from checking our records, yo...  2020-10-27 15:05:52
# 2                                                NaN                  NaN
# 3  What do you find troublesome about the update?...  2020-10-26 14:58:29
# 4                                                NaN                  NaN
#
#   sortOrder      appId
# 0    newest  com.anydo
# 1    newest  com.anydo
# 2    newest  com.anydo
# 3    newest  com.anydo
# 4    newest  com.anydo

# %%
df.sample(5)
# Out:
#                                                 reviewId         userName  \
# 11443  gp:AOqpTOGmsNy7iMUNHtloUxseINn8Lh0PQ1STzJ3SN-R...      Jules Cesar
# 6673   gp:AOqpTOEFYjM7v7ev8Zk-Rd9pqEGDNXQ-_-g2i0aSEfL...      Laura Welch
# 4348   gp:AOqpTOHrvbvHGLx1LXU2331OJto0J765uLG_H4S_5CV...         Phyo Swe
# 4015   gp:AOqpTOHK8BmDTORWWkRxxgwc_jfMQo9hCTRBxYGgFip...  HIMANSHU MALLIK
# 1998   gp:AOqpTOGtxx5v-hHiPYebL67YZaAmgN1dQ-nPrlSgh6v...    Sheila7 Brown
#
#                                                userImage  \
# 11443  https://play-lh.googleusercontent.com/a-/AOh14...
# 6673   https://play-lh.googleusercontent.com/-pEYQR7H...
# 4348   https://play-lh.googleusercontent.com/a-/AOh14...
# 4015   https://play-lh.googleusercontent.com/a-/AOh14...
# 1998   https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                                  content  score  \
# 11443  My best calendar app. It has everything I need...      5
# 6673   This is the best habit app I have used so far ...      5
# 4348      Can't buy the pro version. I love this app tho      3
# 4015   Totally a black screen coming when ever we are...      2
# 1998   It just vibrate I never get an alert. It only ...      1
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 11443              0                  NaN  2020-10-14 02:24:14
# 6673               0                  NaN  2020-09-13 10:48:33
# 4348               0               4.22.0  2020-09-11 22:27:05
# 4015               0                  NaN  2020-10-19 11:30:25
# 1998               0                  NaN  2020-06-06 15:23:56
#
#                                             replyContent            repliedAt  \
# 11443                                                NaN                  NaN
# 6673   Thank you for your review and suggestions Laur...  2020-09-13 18:56:13
# 4348   Hi,\nPlease make sure you're logged in to your...  2020-09-13 22:08:29
# 4015   Hi, if you are using the free version, please ...  2020-10-21 06:54:06
# 1998                                                 NaN                  NaN
#
#       sortOrder                appId
# 11443    newest  com.appgenix.bizcal
# 6673     newest         com.habitnow
# 4348     newest         cc.forestapp
# 4015     newest         cc.forestapp
# 1998     newest    com.ticktick.task

# %% [markdown]
# # 3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12495 entries, 0 to 12494
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              12495 non-null  object
#  1   userName              12495 non-null  object
#  2   userImage             12495 non-null  object
#  3   content               12495 non-null  object
#  4   score                 12495 non-null  int64
#  5   thumbsUpCount         12495 non-null  int64
#  6   reviewCreatedVersion  10333 non-null  object
#  7   at                    12495 non-null  object
#  8   replyContent          5818 non-null   object
#  9   repliedAt             5818 non-null   object
#  10  sortOrder             12495 non-null  object
#  11  appId                 12495 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# # 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    2162
# at                         0
# replyContent            6677
# repliedAt               6677
# sortOrder                  0
# appId                      0
# dtype: int64

# %% [markdown]
# # 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#               score  thumbsUpCount
# count  12495.000000   12495.000000
# mean       3.094198       3.047459
# std        1.457693      14.303903
# min        1.000000       0.000000
# 25%        2.000000       0.000000
# 50%        3.000000       0.000000
# 75%        4.000000       1.000000
# max        5.000000     397.000000

# %% [markdown]
# # 6. Are there any duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 7. How is the correlation between cols?

# %%
df.corr(numeric_only=True)
# Out:
#                   score  thumbsUpCount
# score          1.000000      -0.047061
# thumbsUpCount -0.047061       1.000000

# %% [markdown]
# # Data Cleaning

# %%
columns_to_drop = ['reviewCreatedVersion', 'repliedAt', 'replyContent']

# %%
df.drop(columns=columns_to_drop, inplace=True, axis=1)

# %%
df.sample(5)
# Out:
#                                                 reviewId  \
# 11045  gp:AOqpTOGGzWX-fm9PD3SmmGHXIAQc-pyjBg7deui_F0N...
# 11380  gp:AOqpTOEcXZXFUhlL846rrqBYitAjdzT0zkOOsUa_wpL...
# 11077  gp:AOqpTOFhv_HYCrHLr7UQO7JRQRXTNv-m9A5KQo4g5Rm...
# 2051   gp:AOqpTOEGFwk11gI7g7PihsDIddDP-tp8G2meLUYftMy...
# 5671   gp:AOqpTOEhPiv7aAgnDrxkOoQBZjGnjivewQ_rjZr4UA2...
#
#                     userName  \
# 11045          A&Bequestrian
# 11380       Kevin Zilverberg
# 11077                Vesna S
# 2051   Abdelrahman Elbosraty
# 5671              Sharat Das
#
#                                                userImage  \
# 11045  https://play-lh.googleusercontent.com/-VXmN-bW...
# 11380  https://play-lh.googleusercontent.com/a-/AOh14...
# 11077  https://play-lh.googleusercontent.com/-W-gyNT6...
# 2051   https://play-lh.googleusercontent.com/a-/AOh14...
# 5671   https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                                  content  score  \
# 11045  Overall i like this app, but i use it to make ...      3
# 11380                Integrates Google Tasks in calendar      5
# 11077  It would be higher rating but I can't delite s...      3
# 2051   Help! The widgets are not working. It always s...      1
# 5671                                                Good      5
#
#        thumbsUpCount                   at sortOrder                   appId
# 11045              0  2020-06-13 13:47:37    newest     com.appgenix.bizcal
# 11380              0  2020-10-24 06:56:53    newest     com.appgenix.bizcal
# 11077             12  2020-03-21 05:50:12    newest     com.appgenix.bizcal
# 2051               0  2020-03-08 10:07:11    newest       com.ticktick.task
# 5671               0  2020-08-09 07:43:09    newest  com.oristats.habitbull

# %%
import re

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)
    return text

# %%
df['content_clean'] = df['content'].apply(clean_text)

# %%
df.head()
# Out:
#                                             reviewId  \
# 0  gp:AOqpTOEhZuqSqqWnaKRgv-9ABYdajFUB0WugPGh-SG-...
# 1  gp:AOqpTOH0WP4IQKBZ2LrdNmFy_YmpPCVrV3diEU9KGm3...
# 2  gp:AOqpTOEMCkJB8Iq1p-r9dPwnSYadA5BkPWTf32Z1azu...
# 3  gp:AOqpTOGFrUWuKGycpje8kszj3uwHN6tU_fd4gLVFy9z...
# 4  gp:AOqpTOHls7DW8wmDFzTkHwxuqFkdNQtKHmO6Pt9jhZE...
#
#                            userName  \
# 0                          Eric Tie
# 1                        john alpha
# 2                       Sudhakar .S
# 3  SKGflorida@bellsouth.net DAVID S
# 4                     Louann Stoker
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a-/AOh14...
# 3  https://play-lh.googleusercontent.com/-75aK0WF...
# 4  https://play-lh.googleusercontent.com/-pBcY_Z-...
#
#                                              content  score  thumbsUpCount  \
# 0                      I cannot open the app anymore      1              0
# 1  I have been begging for a refund from this app...      1              0
# 2  Very costly for the premium version (approx In...      1              0
# 3  Used to keep me organized, but all the 2020 UP...      1              0
# 4                                Dan Birthday Oct 28      1              0
#
#                     at sortOrder      appId  \
# 0  2020-10-27 21:24:41    newest  com.anydo
# 1  2020-10-27 14:03:28    newest  com.anydo
# 2  2020-10-27 08:18:40    newest  com.anydo
# 3  2020-10-26 13:28:07    newest  com.anydo
# 4  2020-10-26 06:10:50    newest  com.anydo
#
#                                        content_clean
# 0                      i cannot open the app anymore
# 1  i have been begging for a refund from this app...
# 2  very costly for the premium version approx ind...
# 3  used to keep me organized but all the 2020 upd...
# 4                                dan birthday oct 28

# %%
from textblob import TextBlob

# %%
def get_polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df['polarity'] = df['content_clean'].apply(get_polarity)

# %%
df.head()
# Out:
#                                             reviewId  \
# 0  gp:AOqpTOEhZuqSqqWnaKRgv-9ABYdajFUB0WugPGh-SG-...
# 1  gp:AOqpTOH0WP4IQKBZ2LrdNmFy_YmpPCVrV3diEU9KGm3...
# 2  gp:AOqpTOEMCkJB8Iq1p-r9dPwnSYadA5BkPWTf32Z1azu...
# 3  gp:AOqpTOGFrUWuKGycpje8kszj3uwHN6tU_fd4gLVFy9z...
# 4  gp:AOqpTOHls7DW8wmDFzTkHwxuqFkdNQtKHmO6Pt9jhZE...
#
#                            userName  \
# 0                          Eric Tie
# 1                        john alpha
# 2                       Sudhakar .S
# 3  SKGflorida@bellsouth.net DAVID S
# 4                     Louann Stoker
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a-/AOh14...
# 3  https://play-lh.googleusercontent.com/-75aK0WF...
# 4  https://play-lh.googleusercontent.com/-pBcY_Z-...
#
#                                              content  score  thumbsUpCount  \
# 0                      I cannot open the app anymore      1              0
# 1  I have been begging for a refund from this app...      1              0
# 2  Very costly for the premium version (approx In...      1              0
# 3  Used to keep me organized, but all the 2020 UP...      1              0
# 4                                Dan Birthday Oct 28      1              0
#
#                     at sortOrder      appId  \
# 0  2020-10-27 21:24:41    newest  com.anydo
# 1  2020-10-27 14:03:28    newest  com.anydo
# 2  2020-10-27 08:18:40    newest  com.anydo
# 3  2020-10-26 13:28:07    newest  com.anydo
# 4  2020-10-26 06:10:50    newest  com.anydo
#
#                                        content_clean  polarity
# 0                      i cannot open the app anymore     0.000
# 1  i have been begging for a refund from this app...     0.000
# 2  very costly for the premium version approx ind...     0.360
# 3  used to keep me organized but all the 2020 upd...    -0.175
# 4                                dan birthday oct 28     0.000

# %%
def get_sentiment_label(polarity_score):
    if polarity_score > 0:
        return 'Positive'
    elif polarity_score < 0:
        return 'Negative'
    else:
        return 'Neutral'

# %%
df['sentiment'] = df['polarity'].apply(get_sentiment_label)

# %%
df.head()
# Out:
#                                             reviewId  \
# 0  gp:AOqpTOEhZuqSqqWnaKRgv-9ABYdajFUB0WugPGh-SG-...
# 1  gp:AOqpTOH0WP4IQKBZ2LrdNmFy_YmpPCVrV3diEU9KGm3...
# 2  gp:AOqpTOEMCkJB8Iq1p-r9dPwnSYadA5BkPWTf32Z1azu...
# 3  gp:AOqpTOGFrUWuKGycpje8kszj3uwHN6tU_fd4gLVFy9z...
# 4  gp:AOqpTOHls7DW8wmDFzTkHwxuqFkdNQtKHmO6Pt9jhZE...
#
#                            userName  \
# 0                          Eric Tie
# 1                        john alpha
# 2                       Sudhakar .S
# 3  SKGflorida@bellsouth.net DAVID S
# 4                     Louann Stoker
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a-/AOh14...
# 3  https://play-lh.googleusercontent.com/-75aK0WF...
# 4  https://play-lh.googleusercontent.com/-pBcY_Z-...
#
#                                              content  score  thumbsUpCount  \
# 0                      I cannot open the app anymore      1              0
# 1  I have been begging for a refund from this app...      1              0
# 2  Very costly for the premium version (approx In...      1              0
# 3  Used to keep me organized, but all the 2020 UP...      1              0
# 4                                Dan Birthday Oct 28      1              0
#
#                     at sortOrder      appId  \
# 0  2020-10-27 21:24:41    newest  com.anydo
# 1  2020-10-27 14:03:28    newest  com.anydo
# 2  2020-10-27 08:18:40    newest  com.anydo
# 3  2020-10-26 13:28:07    newest  com.anydo
# 4  2020-10-26 06:10:50    newest  com.anydo
#
#                                        content_clean  polarity sentiment
# 0                      i cannot open the app anymore     0.000   Neutral
# 1  i have been begging for a refund from this app...     0.000   Neutral
# 2  very costly for the premium version approx ind...     0.360  Positive
# 3  used to keep me organized but all the 2020 upd...    -0.175  Negative
# 4                                dan birthday oct 28     0.000   Neutral

# %%
df.sample(10)
# Out:
#                                                 reviewId             userName  \
# 966    gp:AOqpTOGNl80VFBnrfrVGuvbEWouT3wkCxpks026Nqpm...      Michael Banning
# 1685   gp:AOqpTOEi7XUhPP5FMVIMfEXCJkaBS1T7cHh4jCh3qOr...  Demetre Papaiakovou
# 10032  gp:AOqpTOH2U2UGO1klCuBCxhfocTwZ_9q-3mPVWkXx9rt...       Chrissy Kempel
# 1622   gp:AOqpTOESWyNk8Ec_1mVvC-9ZSuvmhHT1pfILXA8iCh0...        Joe Parkinson
# 187    gp:AOqpTOFI9kMoNbYugrSj8xxN0lM_HSjbpb2h2bZiLSa...          Skip Bieber
# 6618   gp:AOqpTOGJUEg1nvx1Enu7AwgxnneX-7qprPXdHvYM9wK...        Frank Charles
# 1828   gp:AOqpTOGPIyvCggHXpyFhEK9Q8xA0XpSaTxZt2Ekvg9C...                 Zo P
# 2182   gp:AOqpTOERIUcWExpcbv6-l_y9foHEsJclh_RxSQjZWM6...       Danushka Wasuu
# 985    gp:AOqpTOGrrj7kRmTcYtGfOfNeuTaOEFs63ZfkWL2yXyu...           Leon Botha
# 654    gp:AOqpTOHQW75Qjv4PhSMTYpQBgDSvzkDeqG37ixJKpt_...           Eric Rupia
#
#                                                userImage  \
# 966    https://play-lh.googleusercontent.com/a-/AOh14...
# 1685   https://play-lh.googleusercontent.com/a-/AOh14...
# 10032  https://play-lh.googleusercontent.com/a-/AOh14...
# 1622   https://play-lh.googleusercontent.com/a-/AOh14...
# 187    https://play-lh.googleusercontent.com/a-/AOh14...
# 6618   https://play-lh.googleusercontent.com/a-/AOh14...
# 1828   https://play-lh.googleusercontent.com/-aPEqOG8...
# 2182   https://play-lh.googleusercontent.com/a-/AOh14...
# 985    https://play-lh.googleusercontent.com/a-/AOh14...
# 654    https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                                  content  score  \
# 966    PROBLEM WITH NEW UPDATE. Since the latest upda...      1
# 1685                        Very simple and easy to use.      4
# 10032  It worked for the first week. Now I can't add ...      2
# 1622   I've been switching between task apps for year...      4
# 187    EVERY service I attempted to connect (Gmail, G...      1
# 6618                              Best app keep it up 👍👍      5
# 1828         Perfect software for actio items management      5
# 2182   widget is not working completely. It does not ...      2
# 985    Via Google assistant, not good. I get the feel...      1
# 654    Easy to use and very straightforward, no fuss ...      4
#
#        thumbsUpCount                   at sortOrder              appId  \
# 966                4  2020-10-10 21:10:08    newest        com.todoist
# 1685               0  2020-06-03 01:38:34    newest        com.todoist
# 10032              2  2018-08-30 09:36:06    newest  com.tasks.android
# 1622               0  2020-07-12 02:00:09    newest        com.todoist
# 187                5  2020-06-18 06:56:18    newest          com.anydo
# 6618               0  2020-10-18 22:20:19    newest       com.habitnow
# 1828               0  2020-10-02 19:32:40    newest        com.todoist
# 2182               3  2020-01-13 08:50:05    newest  com.ticktick.task
# 985               21  2020-09-26 17:08:53    newest        com.todoist
# 654                3  2020-07-13 13:51:09    newest          com.anydo
#
#                                            content_clean  polarity sentiment
# 966    problem with new update since the latest updat...  0.191631  Positive
# 1685                         very simple and easy to use  0.216667  Positive
# 10032  it worked for the first week now i cant add a ...  0.250000  Positive
# 1622   ive been switching between task apps for years...  0.216667  Positive
# 187    every service i attempted to connect gmail gta...  0.000000   Neutral
# 6618                                best app keep it up   1.000000  Positive
# 1828         perfect software for actio items management  1.000000  Positive
# 2182   widget is not working completely it does not s...  0.100000  Positive
# 985    via google assistant not good i get the feelin... -0.294444  Negative
# 654    easy to use and very straightforward no fuss j...  0.640278  Positive

# %% [markdown]
# # Visualization & Insights

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
sentimemt_counts = df['sentiment'].value_counts()

# %%
print(sentimemt_counts)
# Out:
# sentiment
# Positive    8216
# Neutral     2258
# Negative    2021
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=df, x='sentiment', order=['Positive', 'Negative', 'Neutral'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# From the count-plot we can conclude that about 70% reviews are positive and the remaining 30% includes almost equal part of negative and neutral reviews.
#
# It means, the core product is good. We don't need to change the whole app. But, we can also see 25% customers are not satisfied and we can't ignore them.

# %% [markdown]
# # Positive Reviews

# %%
positive_text = " ".join(review for review in df[df['sentiment'] == 'Positive']
                         ['content_clean'] )

# %%
wordcloud_positive = WordCloud(background_color='white', collocations=False).generate(positive_text)

# %%
print("\n--- Word Cloud for Positive Reviews ---")
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.axis("off")  
plt.title('Most Common Words in Positive Reviews')
plt.show()
# Out:
# --- Word Cloud for Positive Reviews ---

# %% [markdown]
# From the positive reviews we got that users consistently praise the app's simplicity and ease of use.
#
# It's our Unique Selling Proposition(USP) that customer loves because of easy interface.

# %% [markdown]
# # Negative Reviews

# %%
negative_text = " ".join(review for review in df[df['sentiment'] == 'Negative']['content_clean'])

# %%
wordcloud_negative = WordCloud(background_color="black", colormap="Reds", collocations=False).generate(negative_text)

# %%
print("\n--- Word Cloud for Negative Reviews ---")
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.axis("off")
plt.title('Most Common Words in Negative Reviews')
plt.show()
# Out:
# --- Word Cloud for Negative Reviews ---

# %% [markdown]
# The primary source of customer dissatisfaction is technical performance, not missing features.
#
# It means we have to work more on functionality of app not in new features. Our top priority is to keep the app stable and more fast.

# %% [markdown]
# 1. Overall Sentiment
#
#    - Around 70% of reviews are positive, which shows that users genuinely like the core product.
#
# 2. Strengths (Positive Reviews)
#
#    - The biggest strength highlighted by users is the app’s simplicity and ease of use.
#
#    - This is your key value proposition — keep emphasizing it in marketing and product messaging.
#
# 3. Weaknesses (Negative Reviews)
#
#    - The critical issues raised in negative reviews are not about   missing features, but about technical problems such as crashes and slow performance.
#
#    - This indicates the product-market fit is strong, but the execution (stability and speed) needs improvement.
